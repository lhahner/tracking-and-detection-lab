# %% [markdown]
# ## CNN-Backbone

# %% [markdown]
# Most of the common object detection systems like YOLOv1-10, Faster R-CNN and DETR have CNN as backbone. This notebook describes why even in modern Neural Network architectures a CNN is needed as backbone.

# %% [markdown]
# ## 1. Core CNN implementation

# %% [markdown]
# Setting up the CNN in only four steps.

# %% [markdown]
# #### 1.1 Importing the required libaries

# %% [markdown]
# #### 1.2 Loading and preprocessing the dataset

# %% [markdown]
# #### 1.3 Defining the CNN architecture

# %% [markdown]
# #### 1.4 Training the CNN model

# %% [markdown]
# #### 1.5 Evaluating the model
